# %%
import pandas as pd
df_contatos = pd.read_excel('lista_envio.xlsx')
display(df_contatos)
# Out:
#                    Pessoa        Número  \
# 0       Cleberson Pertile  554191970494
# 1      Fernando Varaschin  554691080584
# 2           coisa + chata  554599323122
# 3      Jhonny Vendruscolo  554699165657
# 4        Daniel Varaschin  554699792026
# 5                    Enzo  553591704999
# 6        Fabrício Pereira  554691324445
# 7      Luiz Augusto Alves  554691271269
# 8          Rodrigo Picolo  554688281914
# 9                   Mauro  554691415869
# 10  Luiz Fernando Novello  554691187766
#
#                                              Mensagem
# 0   vc participou de um teste de automatização  pa...
# 1   vc participou de um teste de automatização  pa...
# 2   vc participou de um teste de automatização  pa...
# 3   vc participou de um teste de automatização  pa...
# 4   vc participou de um teste de automatização  pa...
# 5   vc participou de um teste de automatização  pa...
# 6   vc participou de um teste de automatização  pa...
# 7   vc participou de um teste de automatização  pa...
# 8   vc participou de um teste de automatização  pa...
# 9   vc participou de um teste de automatização  pa...
# 10  vc participou de um teste de automatização  pa...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib

navegador = webdriver.Chrome()
navegador.get('https://web.whatsapp.com/')

#procura elemento pelo id. side só aparece após ter feito login
while len(navegador.find_elements_by_id('side')) < 1:
    time.sleep(2)
    
#montar msg e enviar
for i, mensagem in enumerate(df_contatos['Mensagem']):
    pessoa = df_contatos.loc[i, 'Pessoa']
    numero = df_contatos.loc[i, 'Número']
    texto = urllib.parse.quote(f'Boa tarde {pessoa}, {mensagem}')
    link = f'https://web.whatsapp.com/send?phone={numero}&text={texto}'
    navegador.get(link)
    while len(navegador.find_elements_by_id('side')) < 1:
        time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div[2]/div/div[2]').send_keys(Keys.ENTER)
    time.sleep(10)
